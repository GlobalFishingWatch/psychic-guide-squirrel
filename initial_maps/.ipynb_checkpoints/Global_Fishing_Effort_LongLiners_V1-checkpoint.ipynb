# %% [markdown]
# # Global Fishing Effort Purse Seiners

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib import colors,colorbar
import matplotlib
# %matplotlib inline
import csv 
import math
# from scipy import stats

# %%
import bq  
client = bq.Client.Get()

# %%
def Query(q):
    t0 = time.time()
    answer = client.ReadTableRows(client.Query(q)['configuration']['query']['destinationTable'])
    print 'Query time: ' + str(time.time() - t0) + ' seconds.'
    return answer

# %%
# how many vessels?
q = ''' SELECT count(*) FROM
      [scratch_global_fishing_raster.classification_results_20160506]
    WHERE max_label_label = "Purse seine" '''
neural_trawlers = int(Query(q)[0][0])

q = ''' SELECT count(*) FROM
      [scratch_global_fishing_raster.classification_results_20160506]
     WHERE max_label_label = "Purse seine"
     and max_label_score > .8'''
neural_trawlers_highconfidence = int(Query(q)[0][0])

q = ''' SELECT count(*) FROM
      [scratch_global_fishing_raster.classification_results_20160506]
     WHERE max_label_label = "Purse seine"
     and mmsi in(select string(mmsi) from [scratch_bjorn.2015_combined_fishing])'''
neural_combined_trawlers = int(Query(q)[0][0])

q = ''' SELECT count(*) FROM
      [scratch_global_fishing_raster.classification_results_20160506]
     WHERE max_label_label = "Purse seine"
     and mmsi in(select string(mmsi) from [scratch_bjorn.2015_combined_fishing])
     and max_label_score > .8'''
neural_combined_trawlers_highconfidence = int(Query(q)[0][0])
# Out:
# Waiting on bqjob_r1ec027a92302283d_00000154882c329a_1 ... (0s) Current status: DONE
# Query time: 2.4006550312 seconds.
# Waiting on bqjob_r325b7ca0a17ecb64_00000154882c3bfb_2 ... (0s) Current status: DONE
# Query time: 2.52455711365 seconds.
# Waiting on bqjob_r3e563f5e0da0649b_00000154882c45d8_3 ... (0s) Current status: DONE
# Query time: 2.41341900826 seconds.
# Waiting on bqjob_r6d140e23aaab5d58_00000154882c4f47_4 ... (0s) Current status: DONE
# Query time: 2.67493510246 seconds.

# %%
print "Classified Purse Seiners:", neural_trawlers
print "Classified Purse Seiners High Confidence:", neural_trawlers_highconfidence
print "Classified Purse Seiners that are Likely Fishing Vessels:", neural_combined_trawlers
print "Classified Purse Seiners High Confidence that are Likely Fishing Vessels :", neural_combined_trawlers_highconfidence
# Out:
# Classified Purse Seiners: 15570
# Classified Purse Seiners High Confidence: 10041
# Classified Purse Seiners that are Likely Fishing Vessels: 9289
# Classified Purse Seiners High Confidence that are Likely Fishing Vessels : 6803

# %%
q = '''
SELECT
  INTEGER(lat*2) lat_bin,
  INTEGER(lon*2) lon_bin,
  SUM(fishing_hours) fishing_hours
FROM (
  SELECT
    lat,
    lon,
    (last_hours + next_hours)/2 fishing_hours
  FROM
    [scratch_global_fishing_raster.2015_with_score_and_hours]
  WHERE
    measure_new_score > .5
    AND lat <90
    AND lon <180
    AND mmsi IN (
    SELECT
      INTEGER(mmsi)
    FROM
      [scratch_global_fishing_raster.classification_results_20160506]
    WHERE
      max_label_label = "Purse seine" )
    AND seg_id IN (
    SELECT
      seg_id,
    FROM
      [scratch_david_seg_analysis.2015_segments]
    WHERE
      NOT( point_count<=20
        OR (point_count<100
          AND point_count = terrestrial_positions)
        OR (min_lat >= 0
          AND max_lat <= 0.109225)
        OR (min_lon >= 0
          AND max_lon <= 0.109225) )))
GROUP BY
  lat_bin,
  lon_bin
'''

fishing_grid = Query(q)
# Out:
# Waiting on bqjob_r17a6f8e30237da1c_00000154882ec0ba_6 ... (0s) Current status: DONE
# Query time: 2.61872506142 seconds.

# %%
cellsize = .5
one_over_cellsize = 2
max_lat = 90
min_lat = -90
min_lon = -180
max_lon = 180

num_lats = (max_lat-min_lat)*one_over_cellsize
num_lons = (max_lon-min_lon)*one_over_cellsize

grid = np.zeros(shape=(num_lats,num_lons))

for row in fishing_grid:
    lat = int(row[0])
    lon = int(row[1])
    lat_index = lat-min_lat*one_over_cellsize
    lon_index = lon-min_lon*one_over_cellsize
    grid[lat_index][lon_index] = float(row[2])

# %%
plt.rcParams["figure.figsize"] = [12,7]

cutoff = 0 # 4 degress away from the pole
firstlat = 90-cutoff
lastlat = -90+cutoff
firstlon = -180
lastlon = 180
scale = cellsize
one_over_cellsize = 2

fishing_days_truncated = grid[one_over_cellsize*cutoff:(180*one_over_cellsize)-cutoff*one_over_cellsize][:]

numlats = int((firstlat-lastlat)*one_over_cellsize+.5)
numlons = int((lastlon-firstlon)*one_over_cellsize+.5)
    
lat_boxes = np.linspace(lastlat,firstlat,num=numlats,endpoint=False)
lon_boxes = np.linspace(firstlon,lastlon,num=numlons,endpoint=False)

fig = plt.figure()
m = Basemap(llcrnrlat=lastlat, urcrnrlat=firstlat,
          llcrnrlon=lastlon, urcrnrlon=firstlon, lat_ts=0, projection='robin',resolution="h", lon_0=0)

m.drawmapboundary(fill_color='#111111')
# m.drawcoastlines(linewidth=.2)
m.fillcontinents('#111111',lake_color='#111111')#, lake_color, ax, zorder, alpha)

x = np.linspace(-180, 180, 360*one_over_cellsize)
y = np.linspace(lastlat, firstlat, (firstlat-lastlat)*one_over_cellsize)
x, y = np.meshgrid(x, y)
converted_x, converted_y = m(x, y)
from matplotlib import colors,colorbar

maximum = grid.max()
minimum = 1

norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)

m.pcolormesh(converted_x, converted_y, fishing_days_truncated, norm=norm, vmin=minimum, vmax=maximum, cmap = plt.get_cmap('viridis'))

t = "Fishing Hours for Trawlers, 2015\nPurse Seiners identified by the Neural Net"
plt.title(t, color = "#ffffff", fontsize=18)

ax = fig.add_axes([0.2, 0.1, 0.4, 0.02]) #x coordinate , 
norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)
lvls = np.logspace(np.log10(minimum),np.log10(maximum),num=8)
cb = colorbar.ColorbarBase(ax,norm = norm, orientation='horizontal', ticks=lvls, cmap = plt.get_cmap('viridis'))

the_labels = []
for l in lvls:
    if l>=1:
        l = int(l)
    the_labels.append(l)

#cb.ax.set_xticklabels(["0" ,round(m3**.5,1), m3, round(m3**1.5,1), m3*m3,round(m3**2.5,1), str(round(m3**3,1))+"+"], fontsize=10)
cb.ax.set_xticklabels(the_labels, fontsize=10, color = "#ffffff")
cb.set_label('Fishing Hours by Two Degree Grid',labelpad=-40, y=0.45, color = "#ffffff")

ax.text(1.7, -0.5, 'Data Source: Orbcomm\nMap by Global Fishing Watch',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='#ffffff', fontsize=6)

plt.savefig("fishing_hours_PurseSeiners_2015_v1.png",bbox_inches='tight',dpi=300,transparent=True,pad_inches=.1, facecolor="#000000")
plt.show()

# %%
q = '''
SELECT
  INTEGER(lat*2) lat_bin,
  INTEGER(lon*2) lon_bin,
  SUM(fishing_hours) fishing_hours
FROM (
  SELECT
    lat,
    lon,
    (last_hours + next_hours)/2 fishing_hours
  FROM
    [scratch_global_fishing_raster.2015_with_score_and_hours]
  WHERE
    measure_new_score > .5
    AND lat <90
    AND lon <180
    AND mmsi IN (
    SELECT
      INTEGER(mmsi)
    FROM
      [scratch_global_fishing_raster.classification_results_20160506]
    WHERE
      max_label_label = "Purse seine" 
      and max_label_score > .8)
    AND seg_id IN (
    SELECT
      seg_id,
    FROM
      [scratch_david_seg_analysis.2015_segments]
    WHERE
      NOT( point_count<=20
        OR (point_count<100
          AND point_count = terrestrial_positions)
        OR (min_lat >= 0
          AND max_lat <= 0.109225)
        OR (min_lon >= 0
          AND max_lon <= 0.109225) )))
GROUP BY
  lat_bin,
  lon_bin
'''

fishing_grid = Query(q)
# Out:
# Waiting on bqjob_r57a169b5803a3ee1_00000154882fb25f_7 ... (15s) Current status: DONE
# Query time: 18.8132119179 seconds.

# %%
cellsize = .5
one_over_cellsize = 2
max_lat = 90
min_lat = -90
min_lon = -180
max_lon = 180

num_lats = (max_lat-min_lat)*one_over_cellsize
num_lons = (max_lon-min_lon)*one_over_cellsize

grid = np.zeros(shape=(num_lats,num_lons))

for row in fishing_grid:
    lat = int(row[0])
    lon = int(row[1])
    lat_index = lat-min_lat*one_over_cellsize
    lon_index = lon-min_lon*one_over_cellsize
    grid[lat_index][lon_index] = float(row[2])

# %%
plt.rcParams["figure.figsize"] = [12,7]

cutoff = 0 # 4 degress away from the pole
firstlat = 90-cutoff
lastlat = -90+cutoff
firstlon = -180
lastlon = 180
scale = cellsize
one_over_cellsize = 2

fishing_days_truncated = grid[one_over_cellsize*cutoff:(180*one_over_cellsize)-cutoff*one_over_cellsize][:]

numlats = int((firstlat-lastlat)*one_over_cellsize+.5)
numlons = int((lastlon-firstlon)*one_over_cellsize+.5)
    
lat_boxes = np.linspace(lastlat,firstlat,num=numlats,endpoint=False)
lon_boxes = np.linspace(firstlon,lastlon,num=numlons,endpoint=False)

fig = plt.figure()
m = Basemap(llcrnrlat=lastlat, urcrnrlat=firstlat,
          llcrnrlon=lastlon, urcrnrlon=firstlon, lat_ts=0, projection='robin',resolution="h", lon_0=0)

m.drawmapboundary(fill_color='#111111')
# m.drawcoastlines(linewidth=.2)
m.fillcontinents('#111111',lake_color='#111111')#, lake_color, ax, zorder, alpha)

x = np.linspace(-180, 180, 360*one_over_cellsize)
y = np.linspace(lastlat, firstlat, (firstlat-lastlat)*one_over_cellsize)
x, y = np.meshgrid(x, y)
converted_x, converted_y = m(x, y)
from matplotlib import colors,colorbar

maximum = grid.max()
minimum = 1

norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)

m.pcolormesh(converted_x, converted_y, fishing_days_truncated, norm=norm, vmin=minimum, vmax=maximum, cmap = plt.get_cmap('viridis'))

t = "Fishing Hours for Trawlers, 2015\nPurse Seiners identified by the Neural Net with Confidence > 0.8"
plt.title(t, color = "#ffffff", fontsize=18)

ax = fig.add_axes([0.2, 0.1, 0.4, 0.02]) #x coordinate , 
norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)
lvls = np.logspace(np.log10(minimum),np.log10(maximum),num=8)
cb = colorbar.ColorbarBase(ax,norm = norm, orientation='horizontal', ticks=lvls, cmap = plt.get_cmap('viridis'))

the_labels = []
for l in lvls:
    if l>=1:
        l = int(l)
    the_labels.append(l)

#cb.ax.set_xticklabels(["0" ,round(m3**.5,1), m3, round(m3**1.5,1), m3*m3,round(m3**2.5,1), str(round(m3**3,1))+"+"], fontsize=10)
cb.ax.set_xticklabels(the_labels, fontsize=10, color = "#ffffff")
cb.set_label('Fishing Hours by Two Degree Grid',labelpad=-40, y=0.45, color = "#ffffff")

ax.text(1.7, -0.5, 'Data Source: Orbcomm\nMap by Global Fishing Watch',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='#ffffff', fontsize=6)

plt.savefig("fishing_hours_PurseSeiners_2015_highconfidence_v1.png",bbox_inches='tight',dpi=300,transparent=True,pad_inches=.1, facecolor="#000000")
plt.show()

# %%
q = '''
SELECT
  INTEGER(lat*2) lat_bin,
  INTEGER(lon*2) lon_bin,
  SUM(fishing_hours) fishing_hours
FROM (
  SELECT
    lat,
    lon,
    (last_hours + next_hours)/2 fishing_hours
  FROM
    [scratch_global_fishing_raster.2015_with_score_and_hours]
  WHERE
    measure_new_score > .5
    and lat <90 
    and lon <180
    AND mmsi IN (
    SELECT
      integer(mmsi)
    FROM
      [scratch_global_fishing_raster.classification_results_20160506]
    WHERE
      max_label_label = "Purse seine"
    and mmsi in(select string(mmsi) from [scratch_bjorn.2015_combined_fishing]))
    AND seg_id IN (
    SELECT
      seg_id,
    FROM
      [scratch_david_seg_analysis.2015_segments]
    WHERE
      NOT( point_count<=20
        OR (point_count<100
          AND point_count = terrestrial_positions)
        OR (min_lat >= 0
          AND max_lat <= 0.109225)
        OR (min_lon >= 0
          AND max_lon <= 0.109225) )))
GROUP BY
  lat_bin,
  lon_bin
'''

fishing_grid = Query(q)
# Out:
# Waiting on bqjob_r4060a10149409082_000001548830e689_8 ... (15s) Current status: DONE
# Query time: 18.2195651531 seconds.

# %%
cellsize = .5
one_over_cellsize = 2
max_lat = 90
min_lat = -90
min_lon = -180
max_lon = 180

num_lats = (max_lat-min_lat)*one_over_cellsize
num_lons = (max_lon-min_lon)*one_over_cellsize

grid = np.zeros(shape=(num_lats,num_lons))

for row in fishing_grid:
    lat = int(row[0])
    lon = int(row[1])
    lat_index = lat-min_lat*one_over_cellsize
    lon_index = lon-min_lon*one_over_cellsize
    grid[lat_index][lon_index] = float(row[2])

# %%
plt.rcParams["figure.figsize"] = [12,7]

cutoff = 0 # 4 degress away from the pole
firstlat = 90-cutoff
lastlat = -90+cutoff
firstlon = -180
lastlon = 180
scale = cellsize
one_over_cellsize = 2

fishing_days_truncated = grid[one_over_cellsize*cutoff:(180*one_over_cellsize)-cutoff*one_over_cellsize][:]

numlats = int((firstlat-lastlat)*one_over_cellsize+.5)
numlons = int((lastlon-firstlon)*one_over_cellsize+.5)
    
lat_boxes = np.linspace(lastlat,firstlat,num=numlats,endpoint=False)
lon_boxes = np.linspace(firstlon,lastlon,num=numlons,endpoint=False)

fig = plt.figure()
m = Basemap(llcrnrlat=lastlat, urcrnrlat=firstlat,
          llcrnrlon=lastlon, urcrnrlon=firstlon, lat_ts=0, projection='robin',resolution="h", lon_0=0)

m.drawmapboundary(fill_color='#111111')
# m.drawcoastlines(linewidth=.2)
m.fillcontinents('#111111',lake_color='#111111')#, lake_color, ax, zorder, alpha)

x = np.linspace(-180, 180, 360*one_over_cellsize)
y = np.linspace(lastlat, firstlat, (firstlat-lastlat)*one_over_cellsize)
x, y = np.meshgrid(x, y)
converted_x, converted_y = m(x, y)
from matplotlib import colors,colorbar

maximum = grid.max()
minimum = 1

norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)

m.pcolormesh(converted_x, converted_y, fishing_days_truncated, norm=norm, vmin=minimum, vmax=maximum, cmap = plt.get_cmap('viridis'))

t = "Fishing Hours for Trawlers, 2015\nPurse Seiners id'd by the Neural Net also in 2015_combined_fishing list"
plt.title(t, color = "#ffffff", fontsize=18)

ax = fig.add_axes([0.2, 0.1, 0.4, 0.02]) #x coordinate , 
norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)
lvls = np.logspace(np.log10(minimum),np.log10(maximum),num=8)
cb = colorbar.ColorbarBase(ax,norm = norm, orientation='horizontal', ticks=lvls, cmap = plt.get_cmap('viridis'))

the_labels = []
for l in lvls:
    if l>=1:
        l = int(l)
    the_labels.append(l)

#cb.ax.set_xticklabels(["0" ,round(m3**.5,1), m3, round(m3**1.5,1), m3*m3,round(m3**2.5,1), str(round(m3**3,1))+"+"], fontsize=10)
cb.ax.set_xticklabels(the_labels, fontsize=10, color = "#ffffff")
cb.set_label('Fishing Hours by Two Degree Grid',labelpad=-40, y=0.45, color = "#ffffff")

ax.text(1.7, -0.5, 'Data Source: Orbcomm\nMap by Global Fishing Watch',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='#ffffff', fontsize=6)

plt.savefig("fishing_hours_PurseSeiners_2015_combinedfishing_v1.png",bbox_inches='tight',dpi=300,transparent=True,pad_inches=.1, facecolor="#000000")
plt.show()

# %%
q = '''
SELECT
  INTEGER(lat*2) lat_bin,
  INTEGER(lon*2) lon_bin,
  SUM(fishing_hours) fishing_hours
FROM (
  SELECT
    lat,
    lon,
    (last_hours + next_hours)/2 fishing_hours
  FROM
    [scratch_global_fishing_raster.2015_with_score_and_hours]
  WHERE
    measure_new_score > .5
    and lat <90 
    and lon <180
    AND mmsi IN (
    SELECT
      integer(mmsi)
    FROM
      [scratch_global_fishing_raster.classification_results_20160506]
    WHERE
      max_label_label = "Purse seine"
      and max_label_score > .8
    and mmsi in(select string(mmsi) from [scratch_bjorn.2015_combined_fishing]))
    AND seg_id IN (
    SELECT
      seg_id,
    FROM
      [scratch_david_seg_analysis.2015_segments]
    WHERE
      NOT( point_count<=20
        OR (point_count<100
          AND point_count = terrestrial_positions)
        OR (min_lat >= 0
          AND max_lat <= 0.109225)
        OR (min_lon >= 0
          AND max_lon <= 0.109225) )))
GROUP BY
  lat_bin,
  lon_bin
'''

fishing_grid = Query(q)
# Out:
# Waiting on bqjob_r2972e5b11116559a_0000015488321266_9 ... (12s) Current status: RUNNING

# %%
cellsize = .5
one_over_cellsize = 2
max_lat = 90
min_lat = -90
min_lon = -180
max_lon = 180

num_lats = (max_lat-min_lat)*one_over_cellsize
num_lons = (max_lon-min_lon)*one_over_cellsize

grid = np.zeros(shape=(num_lats,num_lons))

for row in fishing_grid:
    lat = int(row[0])
    lon = int(row[1])
    lat_index = lat-min_lat*one_over_cellsize
    lon_index = lon-min_lon*one_over_cellsize
    grid[lat_index][lon_index] = float(row[2])

# %%
plt.rcParams["figure.figsize"] = [12,7]

cutoff = 0 # 4 degress away from the pole
firstlat = 90-cutoff
lastlat = -90+cutoff
firstlon = -180
lastlon = 180
scale = cellsize
one_over_cellsize = 2

fishing_days_truncated = grid[one_over_cellsize*cutoff:(180*one_over_cellsize)-cutoff*one_over_cellsize][:]

numlats = int((firstlat-lastlat)*one_over_cellsize+.5)
numlons = int((lastlon-firstlon)*one_over_cellsize+.5)
    
lat_boxes = np.linspace(lastlat,firstlat,num=numlats,endpoint=False)
lon_boxes = np.linspace(firstlon,lastlon,num=numlons,endpoint=False)

fig = plt.figure()
m = Basemap(llcrnrlat=lastlat, urcrnrlat=firstlat,
          llcrnrlon=lastlon, urcrnrlon=firstlon, lat_ts=0, projection='robin',resolution="h", lon_0=0)

m.drawmapboundary(fill_color='#111111')
# m.drawcoastlines(linewidth=.2)
m.fillcontinents('#111111',lake_color='#111111')#, lake_color, ax, zorder, alpha)

x = np.linspace(-180, 180, 360*one_over_cellsize)
y = np.linspace(lastlat, firstlat, (firstlat-lastlat)*one_over_cellsize)
x, y = np.meshgrid(x, y)
converted_x, converted_y = m(x, y)
from matplotlib import colors,colorbar

maximum = grid.max()
minimum = 1

norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)

m.pcolormesh(converted_x, converted_y, fishing_days_truncated, norm=norm, vmin=minimum, vmax=maximum, cmap = plt.get_cmap('viridis'))

t = "Fishing Hours for Trawlers, 2015\nPurse Seiners id'd by the Neural Net in 2015_combined_fishing w/ High Confidence"
plt.title(t, color = "#ffffff", fontsize=18)

ax = fig.add_axes([0.2, 0.1, 0.4, 0.02]) #x coordinate , 
norm = colors.LogNorm(vmin=minimum, vmax=maximum)
# norm = colors.Normalize(vmin=0, vmax=1000)
lvls = np.logspace(np.log10(minimum),np.log10(maximum),num=8)
cb = colorbar.ColorbarBase(ax,norm = norm, orientation='horizontal', ticks=lvls, cmap = plt.get_cmap('viridis'))

the_labels = []
for l in lvls:
    if l>=1:
        l = int(l)
    the_labels.append(l)

#cb.ax.set_xticklabels(["0" ,round(m3**.5,1), m3, round(m3**1.5,1), m3*m3,round(m3**2.5,1), str(round(m3**3,1))+"+"], fontsize=10)
cb.ax.set_xticklabels(the_labels, fontsize=10, color = "#ffffff")
cb.set_label('Fishing Hours by Two Degree Grid',labelpad=-40, y=0.45, color = "#ffffff")

ax.text(1.7, -0.5, 'Data Source: Orbcomm\nMap by Global Fishing Watch',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='#ffffff', fontsize=6)

plt.savefig("fishing_hours_PurseSeiners_2015_combinedfishing_highcon_v1.png",bbox_inches='tight',dpi=300,transparent=True,pad_inches=.1, facecolor="#000000")
plt.show()
